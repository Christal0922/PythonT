# %% [markdown]
# # Bug的常见类型
# + Bug的常见类型
#     + 粗心
#     + 对函数的使用不熟练
#     + 思路不清
#     + 被动掉坑：程序代码逻辑没有错，只是因为用户错误操作或者一些例外情况而导致的程序崩溃，如除数为0
# ![image.png](attachment:image.png)
# + 解决方案
#     + 在代码中段print()变量
#     + 用#注释掉部分代码

# %%
try:
    a=int(input('请输入第一个整数：'))
    b=int(input('请输入第二个整数：'))
    result=a/b
    print("结果为：",result)
except ZeroDivisionError:
    print('对不起，除数不允许为0')
print('程序结束')
# Out:
# 请输入第一个整数：1
# 请输入第二个整数：0
# 对不起，除数不允许为0
# 程序结束

# %%
try:
    a=int(input('请输入第一个整数：'))
    b=int(input('请输入第二个整数：'))
    result=a/b
    
except BaseException as e:
    print("出错了")
    print(e)
else:
    print("结果为：",result)
# Out:
# 请输入第一个整数：1
# 请输入第二个整数：0
# 出错了
# division by zero

# %% [markdown]
# # try-except
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## try except else
# ## try except else finally
# ![image.png](attachment:image.png)

# %% [markdown]
# # python中常见的异常类型
# ![image.png](attachment:image.png)

# %% [markdown]
# # trace back
# ![image.png](attachment:image.png)

# %%
import traceback
try:
    print('-'*30)
    print(1/0)
except:
    traceback.print_exc()
# Out:
# ------------------------------
# Traceback (most recent call last):
#   File "C:\Users\qian9\AppData\Local\Temp/ipykernel_31780/1276579396.py", line 4, in <module>
#     print(1/0)
# ZeroDivisionError: division by zero
